# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf # Para usar fórmulas

# hice pip install en el powershell de windows 

df = pd.read_csv('German_FinTechCompanies.csv')
df.head()
# Out:
#    ID                Name  Status  Original German  Founding year  \
# 0   1         CRX Markets       1              1.0         2012.0
# 1   2             aifinyo       1              1.0         2014.0
# 2   3            fundflow       1              1.0         2016.0
# 3   4      WIR BEWEGEN SH       1              1.0         2015.0
# 4   5  Zusammen Gutes tun       1              1.0         2016.0
#
#                                Founder  \
# 0  Moritz von der Linden; Carlo Kölzer
# 1      Andreas Dubrow; Philipp Kalwies
# 2       Joachim Kaune; Antonio Faralli
# 3  Investitionsbank Schleswig-Holstein
# 4                                  NaN
#
#                             Linkedin-Account Founder  \
# 0  https://www.linkedin.com/in/moritz-von-der-lin...
# 1  https://www.linkedin.com/in/andreas-dubrow/; h...
# 2  https://www.linkedin.com/in/joachim-kaune-26ab...
# 3                                                NaN
# 4                                                NaN
#
#                                     Legal Name  \
# 0                               CRX Markets AG
# 1                                   aifinyo AG
# 2                                Fundflow GmbH
# 3  Investitionsbank Schleswig-Holstein (IB.SH)
# 4                         Evangelische Bank eG
#
#                         Legal form                Street  ...    Segment  \
# 0                               AG  Landsberger Str. 191  ...  Financing
# 1                               AG    Tiergartenstraße 8  ...  Financing
# 2                             GmbH   Prenzlauer Allee 53  ...  Financing
# 3  Anstalt des öffentlichen Rechts      Fleethörn 29-31   ...  Financing
# 4                               eG      Kohlenstraße 132  ...  Financing
#
#                     Subsegment Bank Cooperation  \
# 0         Credit and Factoring                1
# 1         Credit and Factoring                0
# 2         Credit and Factoring                1
# 3  Donation-based Crowdfunding                0
# 4  Donation-based Crowdfunding                0
#
#                              Homepage  \
# 0      https://www.crxmarkets.com/de/
# 1             https://www.aifinyo.de/
# 2                https://fundflow.de/
# 3         https://www.wir-bewegen.sh/
# 4  https://www.zusammen-gutes-tun.de/
#
#                                       E-Mail Insolvency  Liquidation  \
# 0                     support@crxmarkets.com          0            0
# 1  andreas.dubrow@decimo.de\ninfo@aifinyo.de          0            0
# 2                           info@fundflow.de          0            0
# 3                        info@wir-bewegen.sh          0            0
# 4                                 info@eb.de          0            0
#
#   Date of inactivity              Local court  Former name
# 0                NaN                  München          NaN
# 1                NaN                  Dresden   Rechnung48
# 2                NaN  Berlin (Charlottenburg)          NaN
# 3                NaN                     Kiel          NaN
# 4                NaN                   Kassel          NaN
#
# [5 rows x 24 columns]

# %%
df['Name'].head()
# Out:
# 0           CRX Markets
# 1               aifinyo
# 2              fundflow
# 3        WIR BEWEGEN SH
# 4    Zusammen Gutes tun
# Name: Name, dtype: object
