# %%
import pandas as pd 
import numpy as np 
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("US_Regional_Sales_Data.csv")
print(df.head()) 
print(df.dtypes)

df['Unit Price'] = df['Unit Price'].replace('[\$,]', '', regex=True).astype(float)
df['Unit Cost'] = df['Unit Cost'].replace('[\$,]', '', regex=True).astype(float)

# 4. VERIFICAMOS
print("\n--- DESPUÉS DE LA CONVERSIÓN ---")
print("Tipos de datos:")
print(df[['Unit Price', 'Unit Cost']].dtypes)
print("\nPrimeros valores de Unit Price (ahora números):")
print(df['Unit Price'].head())

print(f"Count: {df['Unit Price'].count()}") # muestra el conteo de valores no nulos en la columna "Amount"
print(f"Mean: {df['Unit Price'].mean():.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from scipy import stats
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\hp elitebook\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:147, in __getattr__(name)
#     145 def __getattr__(name):
#     146     if name in submodules:
# --> 147         return _importlib.import_module(f'scipy.{name}')
#     148     else:
#     149         try:
#
# File c:\Users\hp elitebook\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# ...

# %%
df.filter(items=['Unit Price', 'Unit Cost'],axis=1) # describe muestra estadísticas descriptivas de las columnas seleccionadas
# Out:
#       Unit Price  Unit Cost
# 0         1963.1    1001.18
# 1         3939.6    3348.66
# 2         1775.5     781.22
# 3         2324.9    1464.69
# 4         1822.4    1476.14
# ...          ...        ...
# 7986       234.5     121.94
# 7987      3202.6    1921.56
# 7988      3825.7    2792.76
# 7989      1072.0     804.00
# 7990      2211.0    1370.82
#
# [7991 rows x 2 columns]

# %%
df[df["Unit Price"] < 2000].sort_values(by="Discount Applied", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[df["Unit Price"] < 2000].sort_values(by="Discount Applied", ascending=False)
#
# NameError: name 'df' is not defined

# %%
df.reset_index(inplace=True) #para regresear la forma anterior

# %%
df.sort_index()
# Out:
#             index   OrderNumber Sales Channel WarehouseCode ProcuredDate  \
# Unit Price
# 167.5        5248  SO - 0005349        Online  WARE-XYS1001      23/8/19
# 167.5        1681  SO - 0001782        Online  WARE-NMK1003     27/10/18
# 167.5        6190  SO - 0006291        Online  WARE-PUJ1005    1/12/2019
# 167.5        5698  SO - 0005799      In-Store  WARE-UHY1004    1/12/2019
# 167.5        6312  SO - 0006413        Online  WARE-XYS1001    10/3/2020
# ...           ...           ...           ...           ...          ...
# 6559.3       3603  SO - 0003704        Online  WARE-UHY1004     4/2/2019
# 6559.3       3963  SO - 0004064      In-Store  WARE-XYS1001      15/5/19
# 6559.3       4350  SO - 0004451     Wholesale  WARE-NMK1003      23/8/19
# 6559.3       5265  SO - 0005366   Distributor  WARE-NMK1003    1/12/2019
# 6566.0       1776  SO - 0001877   Distributor  WARE-PUJ1005     27/10/18
#
#              OrderDate    ShipDate DeliveryDate CurrencyCode  _SalesTeamID  \
# ...

# %%
df.iloc[0:3, 0:2]
# Out:
#             index  OrderNumber
# Unit Price
# 1963.1          0  SO - 000101
# 3939.6          1  SO - 000102
# 1775.5          2  SO - 000103

# %%
group_by_frame = df.groupby("WarehouseCode")

# %%
df.head()
# Out:
#             index  OrderNumber Sales Channel WarehouseCode ProcuredDate  \
# Unit Price
# 1963.1          0  SO - 000101      In-Store  WARE-UHY1004     31/12/17
# 3939.6          1  SO - 000102        Online  WARE-NMK1003     31/12/17
# 1775.5          2  SO - 000103   Distributor  WARE-UHY1004     31/12/17
# 2324.9          3  SO - 000104     Wholesale  WARE-NMK1003     31/12/17
# 1822.4          4  SO - 000105   Distributor  WARE-NMK1003    10/4/2018
#
#            OrderDate  ShipDate DeliveryDate CurrencyCode  _SalesTeamID  \
# Unit Price
# 1963.1       31/5/18   14/6/18      19/6/18          USD             6
# 3939.6       31/5/18   22/6/18     2/7/2018          USD            14
# 1775.5       31/5/18   21/6/18     1/7/2018          USD            21
# 2324.9       31/5/18  2/6/2018     7/6/2018          USD            28
# 1822.4       31/5/18   16/6/18      26/6/18          USD            22
#
#             _CustomerID  _StoreID  _ProductID  Order Quantity  \
# Unit Price
# ...

# %%
df.reset_index()
# Out:
#       Unit Price  index   OrderNumber Sales Channel WarehouseCode  \
# 0         1963.1      0   SO - 000101      In-Store  WARE-UHY1004
# 1         3939.6      1   SO - 000102        Online  WARE-NMK1003
# 2         1775.5      2   SO - 000103   Distributor  WARE-UHY1004
# 3         2324.9      3   SO - 000104     Wholesale  WARE-NMK1003
# 4         1822.4      4   SO - 000105   Distributor  WARE-NMK1003
# ...          ...    ...           ...           ...           ...
# 7986       234.5   7986  SO - 0008087      In-Store  WARE-MKL1006
# 7987      3202.6   7987  SO - 0008088        Online  WARE-NMK1003
# 7988      3825.7   7988  SO - 0008089        Online  WARE-UHY1004
# 7989      1072.0   7989  SO - 0008090        Online  WARE-NMK1003
# 7990      2211.0   7990  SO - 0008091      In-Store  WARE-UHY1004
#
#      ProcuredDate OrderDate  ShipDate DeliveryDate CurrencyCode  _SalesTeamID  \
# 0        31/12/17   31/5/18   14/6/18      19/6/18          USD             6
# ...

# %%
df.groupby("Sales Channel").mean(numeric_only=True)
# Out:
#                      index  _SalesTeamID  _CustomerID    _StoreID  _ProductID  \
# Sales Channel
# Distributor    4014.833455     22.698182    25.290909  186.717091   24.167273
# In-Store       3966.953608      6.302001    25.402668  185.039418   23.779563
# Online         4011.281649     16.099381    25.671340  181.110103   23.548041
# Wholesale      4023.827548     26.774916    25.331467  182.483763   23.741321
#
#                Order Quantity  Discount Applied    Unit Cost
# Sales Channel
# Distributor          4.572364          0.114196  1456.117055
# In-Store             4.511219          0.115088  1424.761516
# Online               4.493608          0.117682  1434.802256
# Wholesale            4.591265          0.114434  1413.197088

# %% [markdown]
# df.groupby("columna").min(), el índice original (0-10) desaparece y es reemplazado por los valores únicos de la columna que usaste en el groupby

# %%
df['Order Quantity'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['Order Quantity'].head()
#       2 df
#
# NameError: name 'df' is not defined
